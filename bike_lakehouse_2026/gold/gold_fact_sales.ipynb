# %% [markdown]
# # Transformation Logic

# %%
query = """
SELECT
    sd.order_number,
    pr.product_number,
    cu.customer_key,
    sd.order_date,
    sd.ship_date,
    sd.due_date,
    sd.sales_amount,
    sd.quantity,
    sd.price
FROM silver.crm_sales sd
LEFT JOIN gold.dim_products pr
    ON sd.product_number = pr.product_number
LEFT JOIN gold.dim_customers cu
    ON sd.customer_id = cu.customer_id;
"""
df = spark.sql(query)

# %%
df.limit(10).display(df)

# %% [markdown]
# # Writing Gold Table

# %%
df.write.mode("overwrite").format("delta").saveAsTable("workspace.gold.fact_sales")

# %% [markdown]
# ## DQ checks of Gold Table

# %%
# %sql SELECT * FROM workspace.gold.fact_sales LIMIT 10
