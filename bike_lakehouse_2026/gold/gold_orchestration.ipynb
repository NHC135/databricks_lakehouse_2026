# %% [markdown]
# # Orchestration Logic

# %% [markdown]
# This nb runs all gold notebooks in sequence.
# It becomes the single entry point for the gold layer in Databricks Jobs.

# %%
notebooks = [
    "./gold_dim_customers",
    "./gold_dim_products",
    "./gold_fact_sales"
]

for nb in notebooks: 
    print(f"running {nb}") 
    dbutils.notebook.run(nb, timeout_seconds=0)
