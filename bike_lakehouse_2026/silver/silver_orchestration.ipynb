# %% [markdown]
# # Orchestration
# This nb runs all silver transformations notebooks in sequence.
# It becomes a single point of entry for the Silver layer in the Databricks jobs.

# %%
notebooks = { 
 "./crm/silver_crm_cust_info",
 "./crm/silver_crm_prd_info",
 "./crm/silver_crm_sales_details",
 "./erp/silver_erp_cust_az12",
 "./erp/silver_erp_loc_a101",
 "./erp/silver_erp_px_cat_g1v2"  
}

for nb in notebooks: 
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds= 0)
